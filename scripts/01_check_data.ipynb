# %%
import pandas as pd
pd.set_option('max_colwidth', None)

# %%
df1 = pd.read_csv('ContestingSarpanch.csv.gz')
df1
# Out:
#       ElectionType ElectionDuration  District           PanchayatSamiti  SrNo  \
# 0      By Election         May 2022     SIKAR  PIPRALI PANCHAYAT SAMITI     1
# 1      By Election         May 2022     SIKAR  PIPRALI PANCHAYAT SAMITI     2
# 2      By Election         May 2022     SIKAR  PIPRALI PANCHAYAT SAMITI     3
# 3      By Election         May 2022     SIKAR  PIPRALI PANCHAYAT SAMITI     4
# 4      By Election         May 2022     SIKAR  PIPRALI PANCHAYAT SAMITI     5
# ...            ...              ...       ...                       ...   ...
# 68197  By Election         SEP 2021     CHURU    CHURU PANCHAYAT SAMITI     1
# 68198  By Election         SEP 2021  BHILWARA   BANERA PANCHAYAT SAMITI     1
# 68199  By Election         SEP 2021  BHILWARA   BANERA PANCHAYAT SAMITI     2
# 68200  By Election         SEP 2021  BHILWARA   BANERA PANCHAYAT SAMITI     3
# 68201  By Election         SEP 2021  BHILWARA   BANERA PANCHAYAT SAMITI     4
#
# ...

# %%
df2 = pd.read_csv('StatsNomination.csv.gz')
df2
# Out:
#       ElectionType ElectionDuration  District             PanchayatSamiti  \
# 0      By Election         May 2022    JALORE     JALORE PANCHAYAT SAMITI
# 1      By Election         May 2022    JALORE     JALORE PANCHAYAT SAMITI
# 2      By Election         May 2022      KOTA  SULTANPUR PANCHAYAT SAMITI
# 3      By Election         May 2022   BIKANER    BIKANER PANCHAYAT SAMITI
# 4      By Election         May 2022   BIKANER    BIKANER PANCHAYAT SAMITI
# ...            ...              ...       ...                         ...
# 13468  By Election         SEP 2021   DHOLPUR       BARI PANCHAYAT SAMITI
# 13469  By Election         SEP 2021   DHOLPUR       BARI PANCHAYAT SAMITI
# 13470  By Election         SEP 2021   DHOLPUR       BARI PANCHAYAT SAMITI
# 13471  By Election         SEP 2021  BHILWARA     MANDAL PANCHAYAT SAMITI
# 13472  By Election         SEP 2021  BHILWARA     MANDAL PANCHAYAT SAMITI
#
#        SrNo    GramPanchayat  NominationTotalNoOfNominationFilled  \
# ...

# %%
df3 = pd.read_csv('WinnerSarpanch.csv.gz')
df3
# Out:
#       ElectionType ElectionDuration     District             PanchayatSamiti  \
# 0      By Election         May 2022        SIKAR    PIPRALI PANCHAYAT SAMITI
# 1      By Election         May 2022         TONK      NIWAI PANCHAYAT SAMITI
# 2      By Election         May 2022        SIKAR   FATEHPUR PANCHAYAT SAMITI
# 3      By Election         May 2022         TONK      DEOLI PANCHAYAT SAMITI
# 4      By Election         May 2022      UDAIPUR      KOTDA PANCHAYAT SAMITI
# ...            ...              ...          ...                         ...
# 11427  By Election         SEP 2021  HANUMANGARH     BHADRA PANCHAYAT SAMITI
# 11428  By Election         SEP 2021        CHURU  SUJANGARH PANCHAYAT SAMITI
# 11429  By Election         SEP 2021        CHURU    RAJGARH PANCHAYAT SAMITI
# 11430  By Election         SEP 2021        CHURU      CHURU PANCHAYAT SAMITI
# 11431  By Election         SEP 2021     BHILWARA     BANERA PANCHAYAT SAMITI
#
# ...

# %%
df4 = pd.read_csv('WarnWinningPanch.csv.gz')
df4
# Out:
#        ElectionType ElectionDuration  District             PanchayatSamiti  \
# 0       By Election         May 2022    JALORE     JALORE PANCHAYAT SAMITI
# 1       By Election         May 2022    JALORE     JALORE PANCHAYAT SAMITI
# 2       By Election         May 2022      KOTA  SULTANPUR PANCHAYAT SAMITI
# 3       By Election         May 2022   BIKANER    BIKANER PANCHAYAT SAMITI
# 4       By Election         May 2022   BIKANER    BIKANER PANCHAYAT SAMITI
# ...             ...              ...       ...                         ...
# 110291  By Election         SEP 2021   DHOLPUR       BARI PANCHAYAT SAMITI
# 110292  By Election         SEP 2021   DHOLPUR       BARI PANCHAYAT SAMITI
# 110293  By Election         SEP 2021   DHOLPUR       BARI PANCHAYAT SAMITI
# 110294  By Election         SEP 2021  BHILWARA     MANDAL PANCHAYAT SAMITI
# 110295  By Election         SEP 2021  BHILWARA     MANDAL PANCHAYAT SAMITI
#
# ...
